# %% [markdown]
# # **Masking with OpenCV**

# %% [markdown]
# OpenCV is a great tool for image processing and performing computer vision tasks. It is an open-source library that can be used to perform tasks like face detection, objection tracking, landmark detection, and much more.

# %% [markdown]
# Masking is used in Image Processing to output the Region of Interest, or simply the part of the image that we are interested in.
# Now let us do masking on a road image.

# %% [markdown]
# # **Importing all the Necessary Libraries**

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2
# %matplotlib inline

# %% [markdown]
# # **Reading the Image and Displaying it**

# %%
image_color = mpimg.imread("road_image.jpg")

# %%
image_color.shape
# Out:
# (408, 612, 3)

# %%
plt.imshow(image_color)

# %% [markdown]
# # **Displaying Image in Grey Color**

# %%
image_gray = cv2.cvtColor(image_color,cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray, cmap = "gray")
image_gray.shape
# Out:
# (408, 612)

# %% [markdown]
# # **Sorting out the white color out of the image**

# %%
image_copy = np.copy(image_color) 
image_copy.shape
# Out:
# (408, 612, 3)

# %%
image_copy[ (image_copy[:,:,0] < 200) | (image_copy[:,:,1] < 200) |
           (image_copy[:,:,2] < 200) ] = 0

# %%
#Displaying the image
plt.imshow(image_copy, cmap ="gray")
plt.show()

# %% [markdown]
# # **Region Of Interest (ROI) Selection**

# %%
image_color = cv2.imread("road_image.jpg")

# %%
cv2.imshow('Original Image',image_color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
height, width, channels = image_color.shape
channels
# Out:
# 3

# %%
height, width = image_color.shape[:2]

# %%
height
# Out:
# 408

# %%
width
# Out:
# 612

# %%
plt.imshow(image_color);

# %%
image_color.shape
# Out:
# (408, 612, 3)

# %% [markdown]
# # **Converting to Greyscale**

# %%
image_gray = cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray, cmap = 'gray');

# %%
image_gray.shape
# Out:
# (408, 612)

# %% [markdown]
# # **Perform Region Of Interest Masking**

# %%
# Select points of the region of interest (ROI)

ROI = np.array([[(0,height),(0, 350),(45,300),(95, 240), (195,120),(295,0),(325,0),(397,60),(445,100),(505,150),(565,200),(width, 240),(width,height)]], dtype=np.int32)

# define a blank image with all zeros (ie: black) 

blank = np.zeros_like(image_gray)

# %%
blank.shape
# Out:
# (408, 612)

# %%
# Fill the Region of interest with white color (ie: 255)!

mask = cv2.fillPoly(blank, ROI, 255)

# Perform bitwise AND operation to select only the region of interest

masked_image = cv2.bitwise_and(image_gray, mask)

# %%
masked_image.shape
# Out:
# (408, 612)

# %%
plt.imshow(masked_image, cmap ="gray")

# %% [markdown]
# # The key point of masking is that they allow us to focus our computation only on regions of the image that interest us. Focusing our computations on regions that interest us dramatically impacts when we explore topics such as machine learning, image classification, and object detection.

# %% [markdown]
# # Finally, We have successfully masked our image using opencv
