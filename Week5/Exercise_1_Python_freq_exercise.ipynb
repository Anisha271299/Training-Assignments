# %% [markdown]
# #Frequency Distribution using Airline Dataset

# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/Clean_Dataset.csv")
data.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %%
# Checking for null values
data.isna().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
# Frequency distribution of airline:
airline_freq = pd.crosstab(index=data['airline'],columns='Frequency')
airline_freq
# Out:
# col_0      Frequency
# airline
# AirAsia        16098
# Air_India      80892
# GO_FIRST       23173
# Indigo         43120
# SpiceJet        9011
# Vistara       127859

# %%
# Graphical representation
sns.histplot(x='airline',data=data)

# %%
# Frequency distribution of flight:
flight_freq = pd.crosstab(index=data['flight'],columns='Frequency')
flight_freq
# Out:
# col_0   Frequency
# flight
# 6E-102         39
# 6E-105          5
# 6E-113         49
# 6E-121         20
# 6E-123          5
# ...           ...
# UK-988       1381
# UK-993        911
# UK-994       1273
# UK-995       1024
# UK-996       1266
#
# [1561 rows x 1 columns]

# %%
# Graphical representation
sns.histplot(x='flight',data=data)

# %%
# Frequency distribution of source_city
source_city_freq = pd.crosstab(index=data['source_city'],columns='Frequency')
source_city_freq
# Out:
# col_0        Frequency
# source_city
# Bangalore        52061
# Chennai          38700
# Delhi            61343
# Hyderabad        40806
# Kolkata          46347
# Mumbai           60896

# %%
# Graphical representation
sns.histplot(x='source_city',data=data)

# %%
# Frequency distribution of departure_time:
departure_time_freq = pd.crosstab(index=data['departure_time'],columns='Frequency')
departure_time_freq
# Out:
# col_0           Frequency
# departure_time
# Afternoon           47794
# Early_Morning       66790
# Evening             65102
# Late_Night           1306
# Morning             71146
# Night               48015

# %%
# Graphical representation
sns.histplot(x='departure_time',data=data)

# %%
# Frequency distribution of stops:
stops_freq = pd.crosstab(index=data['stops'],columns='Frequency')
stops_freq
# Out:
# col_0        Frequency
# stops
# one             250863
# two_or_more      13286
# zero             36004

# %%
# Graphical representation
sns.histplot(x='stops',data=data)

# %%
# Frequency distribution of arrival_time:
arrival_time_freq = pd.crosstab(index=data['arrival_time'],columns='Frequency')
arrival_time_freq
# Out:
# col_0          Frequency
# arrival_time
# Afternoon          38139
# Early_Morning      15417
# Evening            78323
# Late_Night         14001
# Morning            62735
# Night              91538

# %%
# Graphical representation
sns.histplot(x='arrival_time',data=data)

# %%
# Frequency distribution of destination_city:
destination_city_freq = pd.crosstab(index=data['destination_city'],columns='Frequency')
destination_city_freq
# Out:
# col_0             Frequency
# destination_city
# Bangalore             51068
# Chennai               40368
# Delhi                 57360
# Hyderabad             42726
# Kolkata               49534
# Mumbai                59097

# %%
# Graphical representation
sns.histplot(x='destination_city',data=data)

# %%
# Frequency distribution of class:
class_freq = pd.crosstab(index=data['class'],columns='Frequency')
class_freq
# Out:
# col_0     Frequency
# class
# Business      93487
# Economy      206666

# %%
# Graphical representation
sns.histplot(x='class',data=data)

# %%
# Frequency distribution of duration:
duration_freq = pd.crosstab(index=data['duration'],columns='Frequency')
duration_freq
# Out:
# col_0     Frequency
# duration
# 0.83             52
# 0.92             78
# 1.00            377
# 1.08            553
# 1.17            960
# ...             ...
# 44.50             1
# 45.83             3
# 47.08             1
# 47.75             2
# 49.83             2
#
# [476 rows x 1 columns]

# %%
# Graphical representation
sns.histplot(x='duration',data=data)

# %%
# Frequency distribution of days_left:
days_left_freq = pd.crosstab(index=data['days_left'],columns='Frequency')
days_left_freq
# Out:
# col_0      Frequency
# days_left
# 1               1927
# 2               4026
# 3               4248
# 4               5077
# 5               5392
# 6               5740
# 7               5703
# 8               5767
# 9               5665
# 10              5822
# 11              6417
# 12              6381
# 13              6404
# 14              6349
# 15              6340
# 16              6272
# 17              6419
# 18              6602
# 19              6537
# 20              6502
# 21              6479
# 22              6494
# 23              6401
# 24              6542
# 25              6633
# 26              6573
# 27              6360
# 28              6522
# 29              6397
# 30              6501
# 31              6534
# 32              6585
# 33              6532
# 34              6412
# 35              6291
# 36              6490
# 37              6476
# 38              6512
# 39              6593
# 40              6531
# 41              6525
# ...

# %%
# Graphical representation
sns.histplot(x='days_left',data=data)

# %%
# Frequency distribution of price:
price_freq = pd.crosstab(index=data['price'],columns='Frequency')
price_freq
# Out:
# col_0   Frequency
# price
# 1105          300
# 1106            7
# 1443          180
# 1444           14
# 1526           20
# ...           ...
# 114705          1
# 115211          1
# 116562          1
# 117307          1
# 123071          1
#
# [12157 rows x 1 columns]

# %%
# Graphical representation
sns.histplot(x='price',data=data)
